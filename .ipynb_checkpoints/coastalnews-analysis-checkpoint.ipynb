# %%
#This notebook will be for some intial data analysis on the Coastal Newswatch Data Set
import pandas as pd

# %%
#create data frame from csv file
EO_data_frame = pd.DataFrame.from_csv("DSIDE_data_oceans_and_coasts_news_articles - Sheet1.csv")

# %%
EO_data_frame
# Out:
#                                                    News Article Publish Date  \
# News Article Title
# Unprotected and open to plunder                                     29/05/16
# R303m dedicated towards protecting parts of SA'...                 6/13/2016
# South Africa: Beach Clean-Up to Mark World Ocea...                13/06/2016
# Spare a thought on World Oceans Day                               07/06/2016
# CSIR’s SeaFAR aiding authorities to protect SA’...                   06/2016
# Turning the tide on poaching: Will new policy k...                06/06/2016
# Protecting the oceans from plastic starts inland                  09/06/2016
# Locals fume over Chinese fishing fleets                           22/05/2016
# 3 Chinese vessels escorted to EC harbour on sus...                23/05/2016
# CSIR technology “sees” vessels even if Automati...                03/06/2016
# Navy plays major role in impounding 600 tons of...                26/05/2016
# ...
